# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('rain_data_200.csv')

# %%
df.head()
# Out:
#    hours_of_rain  water_collected
# 0       0.000000         2.993428
# 1       0.050251         1.874225
# 2       0.100503         3.596885
# 3       0.150754         5.498321
# 4       0.201005         2.134708

# %%
plt.scatter(df['hours_of_rain'], df['water_collected'])
plt.title('RainFall_to_Water_Collected')
plt.xlabel('hours_of_rain')
plt.ylabel('water_collected')
# Out:
# Text(0, 0.5, 'water_collected')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      hours_of_rain
# 0         0.000000
# 1         0.050251
# 2         0.100503
# 3         0.150754
# 4         0.201005
# ..             ...
# 195       9.798995
# 196       9.849246
# 197       9.899497
# 198       9.949749
# 199      10.000000
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0       2.993428
# 1       1.874225
# 2       3.596885
# 3       5.498321
# 4       2.134708
#          ...
# 195    32.167620
# 196    29.780024
# 197    32.005943
# 198    31.965664
# 199    29.714059
# Name: water_collected, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_tarin, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_tarin)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      hours_of_rain
# 112       5.628141
# 29        1.457286
# 182       9.145729
# 199      10.000000
# 193       9.698492
# 85        4.271357
# 10        0.502513
# 54        2.713568
# 115       5.778894
# 35        1.758794
# 12        0.603015
# 92        4.623116
# 13        0.653266
# 126       6.331658
# 174       8.743719
# 2         0.100503
# 44        2.211055
# 3         0.150754
# 113       5.678392
# 14        0.703518
# 23        1.155779
# 25        1.256281
# 6         0.301508
# 134       6.733668
# 165       8.291457
# 173       8.693467
# 45        2.261307
# 65        3.266332
# 48        2.412060
# 122       6.130653
# 178       8.944724
# 64        3.216080
# 9         0.452261
# 57        2.864322
# 78        3.919598
# 71        3.567839
# 128       6.432161
# 176       8.844221
# 131       6.582915
# 53        2.663317

# %%
y_test
# Out:
# 112    19.004883
# 29      5.788472
# 182    27.295401
# 199    29.714059
# 193    28.604000
# 85     13.810556
# 10      2.580702
# 54     12.202703
# 115    19.939778
# 35      4.834695
# 12      4.292970
# 92     14.465241
# 13      0.133239
# 126    19.013902
# 174    28.784537
# 2       3.596885
# 44      5.676122
# 3       5.498321
# 113    23.961660
# 14      0.660717
# 23      2.617840
# 25      5.990689
# 6       6.062948
# 134    20.362157
# 165    27.699934
# 173    28.762706
# 45      7.344231
# 65     14.511475
# 48      9.923417
# 122    23.197548
# 178    28.304857
# 64     13.273293
# 9       4.441904
# 57      9.974540
# 78     13.942316
# 71     15.779591
# 128    21.495785
# 176    28.558667
# 131    21.885870
# 53     11.213302
# Name: water_collected, dtype: float64

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.9846322])

# %%
plt.scatter(df['hours_of_rain'], df['water_collected'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.title('Rain_Water_Collection')
plt.xlabel('hours_of_rain')
plt.ylabel('Water_Collected')
# Out:
# Text(0, 0.5, 'Water_Collected')

# %%
m = lr.coef_
m
# Out:
# array([3.0780437])

# %%
b = lr.intercept_
b
# Out:
# 1.4990408734827465

# %%
m * 9.145729 + b
# Out:
# array([29.64999442])
